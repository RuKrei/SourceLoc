# %% [markdown]
# # Source localization
#
# ## Part one
#  - File preparation
#  - BIDS dataset generation

# %%
import os
from os.path import isfile
from configuration import subjects_dir, derivatives_root, concat_raws, use_single_transfile, session
import mne
from utils.utils import FileNameRetriever
#from mne_bids import BIDSPath, read_raw_bids
import glob

# %%
fnr = FileNameRetriever(derivatives_root)

subsubj = "sub-" + subj
subjects_dir = fnr.get_filename(subsubj, "subjects_dir")
bids_derivatives = BIDSPath(subject=subj, datatype="meg", session=session, task="resting", 
                            root=derivatives_root, processing="tsssTransEvePreproc")
print(f"\n\nThe following files with processing= \"tsssTransEvePreproc\" were found: {bids_derivatives.match()}\n\n")

if bids_derivatives.match() == []:
    bids_derivatives = BIDSPath(subject=subj, datatype="meg", session=session, task="resting", 
                            root=derivatives_root, processing="tsssTransNoEvePreproc")

#load data
# This should actually be:
#try:
#    raw = read_raw_bids(bids_path=bids_derivatives)
#except Exception as e:
#    print(e)
#    print("Looking for a proprocessed fif-file without Events...")
#    bids_derivatives.update(processing="tsssTransNoEvePreproc")

# loading manually, as BIDS query returns all kinds of things...
target_dir = os.path.join(derivatives_root, subsubj, "ses-resting", "meg", subsubj)
try:
    rawfile = glob.glob(target_dir + "*tsssTransEvePreproc_meg.fif")[0]              #### breaks if rawfile is not found!
except Exception as e:
    print(e)
# if no events
if not os.path.isfile(rawfile):
    rawfile = glob.glob(target_dir + "*tsssTransNoEvePreproc_meg.fif")[0]

if use_single_transfile == True:
    transfile = fnr.get_single_trans_file(subsubj)
    if isfile(transfile):
        print(f"Skipping coregistration, because a transfile ({transfile}) already exists")
    else:
        print(f"\n\n\n--> Transfile should be called: {transfile}\n\n\n")
        mne.gui.coregistration(subject=subsubj, subjects_dir=subjects_dir, inst=rawfile, advanced_rendering=False) # BIDS: inst=raw.filenames[0])

# %%
import mne
mne.gui.coregistration()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\mne023_4\lib\site-packages\tvtk\tvtk_base.py in validate(self, object, name, value)
#     200                 value = self._rmap[value]
# --> 201             if value not in self._map:
#     202                 match = None
#
# TypeError: argument of type 'NoneType' is not iterable
#
# During handling of the above exception, another exception occurred:
#
# TraitError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22740/2443523717.py in <module>
#       1 import mne
# ----> 2 mne.gui.coregistration()
#
# <decorator-gen-506> in coregistration(tabbed, split, width, inst, subject, subjects_dir, guess_mri_subject, height, head_opacity, head_high_res, trans, scrollable, project_eeg, orient_to_surface, scale_by_distance, mark_inside, interaction, scale, advanced_rendering, head_inside, verbose)
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\mne\gui\__init__.py in coregistration(tabbed, split, width, inst, subject, subjects_dir, guess_mri_subject, height, head_opacity, head_high_res, trans, scrollable, project_eeg, orient_to_surface, scale_by_distance, mark_inside, interaction, scale, advanced_rendering, head_inside, verbose)
#     188                        scale=scale, advanced_rendering=advanced_rendering,
#     189                        head_inside=head_inside)
# --> 190     return _initialize_gui(frame, view)
#     191
#     192
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\mne\gui\__init__.py in _initialize_gui(frame, view)
#      16         return frame.edit_traits(view=view), frame
#      17     else:
# ---> 18         frame.configure_traits(view=view)
#      19         return frame
#      20
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\traits\has_traits.py in configure_traits(self, filename, view, kind, edit, context, handler, id, scrollable, **args)
#    2175             if context is None:
#    2176                 context = self
# -> 2177             rc = toolkit().view_application(
#    2178                 context,
#    2179                 self.trait_view(view),
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\traitsui\qt4\toolkit.py in view_application(self, context, view, kind, handler, id, scrollable, args)
#     240         from . import view_application
#     241
# --> 242         return view_application.view_application(
#     243             context, view, kind, handler, id, scrollable, args
#     244         )
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\traitsui\qt4\view_application.py in view_application(context, view, kind, handler, id, scrollable, args)
#      91     app = QtGui.QApplication.instance()
#      92     if app is None or not is_event_loop_running_qt4(app):
# ---> 93         return ViewApplication(
#      94             context, view, kind, handler, id, scrollable, args
#      95         ).ui.result
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\traitsui\qt4\view_application.py in __init__(self, context, view, kind, handler, id, scrollable, args)
#     128
#     129         # this will block for modal dialogs, but not non-modals
# --> 130         self.ui = self.view.ui(
#     131             self.context,
#     132             kind=self.kind,
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\traitsui\view.py in ui(self, context, parent, kind, view_elements, handler, id, scrollable, args)
#     452             kind = self.kind
#     453
# --> 454         ui.ui(parent, kind)
#     455
#     456         return ui
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\traitsui\ui.py in ui(self, parent, kind)
#     236         )
#     237         self.rebuild = getattr(toolkit(), "ui_" + kind)
# --> 238         self.rebuild(self, parent)
#     239
#     240     def dispose(self, result=None, abort=False):
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\traitsui\qt4\toolkit.py in ui_live(self, ui, parent)
#     171         from . import ui_live
#     172
# --> 173         ui_live.ui_live(ui, parent)
#     174
#     175     def ui_modal(self, ui, parent):
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\traitsui\qt4\ui_live.py in ui_live(ui, parent)
#      51     """Creates a live, non-modal PyQt user interface for a specified UI object.
#      52     """
# ---> 53     _ui_dialog(ui, parent, BaseDialog.NONMODAL)
#      54
#      55
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\traitsui\qt4\ui_live.py in _ui_dialog(ui, parent, style)
#      73         ui.owner = _LiveWindow()
#      74
# ---> 75     BaseDialog.display_ui(ui, parent, style)
#      76
#      77
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\traitsui\qt4\ui_base.py in display_ui(ui, parent, style)
#     296         """Display the UI."""
#     297
# --> 298         ui.owner.init(ui, parent, style)
#     299         ui.control = ui.owner.control
#     300         ui.control._parent = parent
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\traitsui\qt4\ui_live.py in init(self, ui, parent, style)
#     233             bbox = None
#     234
# --> 235         self.add_contents(panel(ui), bbox)
#     236
#     237     def close(self, rc=True):
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\traitsui\qt4\ui_panel.py in panel(ui)
#     272         panel = None
#     273     if nr_groups == 1:
# --> 274         panel = _GroupPanel(content[0], ui).control
#     275     elif nr_groups > 1:
#     276         panel = QtGui.QTabWidget()
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\traitsui\qt4\ui_panel.py in __init__(self, group, ui, suppress_label)
#     568             self._setup_editor(group, editor)
#     569
# --> 570             self._add_splitter_items(content, splitter)
#     571
#     572         elif group.layout in ("tabbed", "fold"):
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\traitsui\qt4\ui_panel.py in _add_splitter_items(self, content, splitter)
#     663                 panel = _GroupPanel(item, self.ui, suppress_label=True).control
#     664             else:
# --> 665                 panel = self._add_items([item])
#     666
#     667             # Add the panel to the splitter.
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\traitsui\qt4\ui_panel.py in _add_items(self, content, outer)
#     872                 # that it is not None (otherwise the main TraitsUI code can change
#     873                 # the "kind" of the created UI object).
# --> 874                 editor.prepare(inner)
#     875                 control = editor.control
#     876
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\traitsui\editor.py in prepare(self, parent)
#     245                 self._update_editor, name, dispatch="ui"
#     246             )
# --> 247         self.init(parent)
#     248         self._sync_values()
#     249         self.update_editor()
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\tvtk\pyface\ui\qt4\scene_editor.py in init(self, parent)
#      47         assert self.value.scene_editor is None, \
#      48                 "The SceneModel may only have one active editor!"
# ---> 49         self._create_scene()
#      50         self.value.activated = True
#      51
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\tvtk\pyface\ui\qt4\scene_editor.py in _create_scene(self)
#      86
#      87         factory = self.factory
# ---> 88         self._scene = factory.scene_class(self.control)
#      89         scene = self._scene
#      90         self.value.scene_editor = scene
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\tvtk\pyface\ui\qt4\decorated_scene.py in __init__(self, parent, **traits)
#      55     ##########################################################################
#      56     def __init__(self, parent, **traits):
# ---> 57         super(DecoratedScene, self).__init__(parent, **traits)
#      58         self._setup_axes_marker()
#      59
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\tvtk\pyface\ui\qt4\scene.py in __init__(self, parent, **traits)
#     323
#     324         # Base class constructor.
# --> 325         super(Scene, self).__init__(parent, **traits)
#     326
#     327         # Setup the default picker.
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\tvtk\pyface\tvtk_scene.py in __init__(self, parent, **traits)
#     220         # Used to set the view of the scene.
#     221         self._def_pos = 1
# --> 222         self.control = self._create_control(parent)
#     223         self._renwin.update_traits()
#     224
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\tvtk\pyface\ui\qt4\decorated_scene.py in _create_control(self, parent)
#      86
#      87         # Create the actual scene content
# ---> 88         self._content = super(DecoratedScene, self)._create_control(self._panel)
#      89         self._panel.setCentralWidget(self._content)
#      90
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\tvtk\pyface\ui\qt4\scene.py in _create_control(self, parent)
#     404
#     405         # Grab the renderwindow.
# --> 406         renwin = self._renwin = tvtk.to_tvtk(window.GetRenderWindow())
#     407         renwin.trait_set(point_smoothing=self.point_smoothing,
#     408                    line_smoothing=self.line_smoothing,
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\tvtk\tvtk_classes.zip\tvtk_classes\tvtk_helper.py in wrap_vtk(obj)
#      63         except ImportError:
#      64             tvtk_class = get_nearest_base_class(obj)
# ---> 65         return tvtk_class(obj)
#      66     else:
#      67         return obj
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\tvtk\tvtk_classes.zip\tvtk_classes\win32_open_gl_render_window.py in __init__(self, obj, update, **traits)
#      40     """
#      41     def __init__(self, obj=None, update=True, **traits):
# ---> 42         tvtk_base.TVTKBase.__init__(self, vtk.vtkWin32OpenGLRenderWindow, obj, update, **traits)
#      43
#      44     current_cursor = traits.Int(0, enter_set=True, auto_set=False, desc=\
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\tvtk\tvtk_base.py in __init__(self, klass, obj, update, **traits)
#     385         # Update the traits based on the values of the VTK object.
#     386         if update:
# --> 387             self.update_traits()
#     388
#     389         # Setup observers for the modified event.
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\tvtk\tvtk_base.py in update_traits(self, obj, event)
#     538             else:
#     539                 try:
# --> 540                     setattr(self, name, val)
#     541                 except traits.TraitError:
#     542                     if name in self._allow_update_failure_:
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\tvtk\tvtk_base.py in validate(self, object, name, value)
#     213             return self._map[value]
#     214         except:
# --> 215             self.error(object, name, value)
#     216
#     217     def info(self):
#
# ~\anaconda3\envs\mne023_4\lib\site-packages\traits\base_trait_handler.py in error(self, object, name, value)
#      72             The proposed new value for the attribute.
#      73         """
# ---> 74         raise TraitError(
#      75             object, name, self.full_info(object, name, value), value
#      76         )
#
# TraitError: The 'stereo_type' trait of a Win32OpenGLRenderWindow instance must be 'crystal_eyes' or 'anaglyph' or 'checkerboard' or 'dresden' or 'emulate' or 'fake' or 'interlaced' or 'left' or 'red_blue' or 'right' or 'split_viewport_horizontal' (or any unique prefix) or 1 or 10 or 11 or 2 or 3 or 4 or 5 or 6 or 7 or 8 or 9, but a value of 'crystal_eyes' <class 'str'> was specified.
